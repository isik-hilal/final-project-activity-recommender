# %% [markdown]
# #### Francesca Logiacco and Hilal Işık
#
# # Final Project
# This project is created and shared by the mentioned authors,
# with each joint author enjoying an equal interest in the undivided whole.
#
#
# ## Goal: 'Find best fitting activity for a Summer Day in Berlin-2022'
#
# We want to give the best summer 2022(may-august) activity tipp according to the interests and max budget information of the user. For that purpose we are going to combine different sources:
#
# 1- Eventbrite
# - Using the Webscraping method to download the free and paid event information
#
# 2- Gratis-in-Berlin
# - Using the Webscraping method to download the event information
#
# 3- Parks and Lakes in Berlin
# - Preparing csv files with the info from Berlin Bezirksamt and Visit Berlin websites.

# %%
import sys
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import random 
import pickle

# %%
# PAID EVENTS
paid_music = pd.read_pickle("paid_music")
paid_film = pd.read_pickle("paid_film")
paid_community = pd.read_pickle("paid_community")
paid_science = pd.read_pickle("paid_science")
paid_sport = pd.read_pickle("paid_sport")
paid_travel_out = pd.read_pickle("paid_travel_out")

# FREE EVENTS
free_music = pd.read_pickle("free_music")
free_community = pd.read_pickle("free_community")
free_film = pd.read_pickle("free_film")
free_ScienceTech = pd.read_pickle("free_ScienceTech")
free_sport = pd.read_pickle("free_sport")
free_travel_out = pd.read_pickle("free_travel_out")  

# PARKS AND LAK
berlin_parks= pd.read_excel('Berlin_Parks_ll.xlsx')
berlin_lakes= pd.read_excel('Berlin_Lakes_ll.xlsx')

# %%
berlin_parks.rename(columns={'name':'park_name'}, inplace=True)
berlin_lakes.rename(columns={'name':'lake_name'}, inplace=True)

# %%
from IPython.display import IFrame
import getpass


def best_tip_berlin():
    





    print('')
    print('')
    print('         ▄▀          〈( ^.^)ノ                          ヘ(^o^ヘ)                 ░░▄▀▀▀▄░▄▄░░░░░░╠▓░░░░')
    print('   █▀▀▀█▀█                                                                        ░░░▄▀▀▄█▄░▀▄░░░▓╬▓▓▓░░  ') 
    print('\033[1m' + '    ▀▄░▄▀       ¡¡¡  Welcome to the BEST TIP in * BERLIN SUMMER 2022 *  !!!      ░░▀░░░░█░▀▄░░░▓▓╬▓▓▓▓░    '+'\033[0m')
    print('     █                                                                           ░░░░░░▐▌░░░░▀▀███████▀') 
    print('   ▄▄█▄▄                 ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ ───==≡≡ΣΣ((( つºل͜º)つ                     ▒▒▄██████▄▒▒▒▒▒▒▒▒▒▒▒▒') 
    print('')
    print('')
    print('')
    print('To get you the Best Tip, we need some information from you.', '\n')
    print('')
    
    your_budget = input('Do you want to spend some money on the event? Please, write here: yes or no. ---> ')
    print('')
    
    
# PAID EVENTS 

    if str.lower(your_budget) == 'yes':
        print('Let me recommend you the best paid events in Berlin', '\n')
        print('Which event category you would prefer?')
        your_interest = input('Select one of these: film, music, science, outdoor, community, sport  --->  ')
        print('')
        
    # music
        if str.lower(your_interest) == 'music':
            print('')
            print('    █▀█▄▄▄▄     ██▄')
            print('    █▀▄▄▄▄█     █▀▀█')
            print(' ▄▄▄█     █  ▄▄▄█')
            print('██▀▄█ ▄██▀█ ███▀█')
            print(' ▀▀▀  ▀█▄█▀ ▀█▄█▀')
            print('')
            
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_music['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_music[paid_music['date'].str.contains(your_date)]
                print('')
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
     # film       
        elif str.lower(your_interest) == 'film':
            print('')
            print('    ░▀▄░░▄▀')
            print('▄▄▄██▄▄▄▄▄░▀█▀▐░▌')
            print('█▒░▒░▒░█▀█░░█░▐░▌')
            print('█░▒░▒░▒█▀█░░█░░█')
            print('█▄▄▄▄▄▄███══════')
            print('')
            
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_film['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_film[paid_film['date'].str.contains(your_date)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
     # community       
        elif str.lower(your_interest) == 'community':
            print('')
            print('               ▄▄   ▐█')
            print('   ▄▄▄   ▄██▄ █▀   █ ▄')
            print(' ▄██▀█▌ ██▄▄ ▐█▀▄ ▐█▀')
            print('▐█▀▀▌   ▄▀▌ ▌ █ ▌  ▌ ▌')
            print('▌▀▄ ▐  ▀▄ ▐▄ ▐▄▐▄ ▐▄ ▐▄')
            print('')
            
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_community['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_community[paid_community['date'].str.contains(your_date)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
     # science
        elif str.lower(your_interest) == 'science':
            print('')
            print('  ▄████▀█▄')
            print(' ▄█████████████████▄')
            print('▄█████.▼.▼.▼.▼.▼.▼▼▼▼')
            print('▄███████▄.▲.▲▲▲▲▲▲▲▲')
            print('████████████████████▀▀')
            print('───')
            print('')
        
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_science['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_science[paid_science['date'].str.contains(your_date)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
     # sport      
        elif str.lower(your_interest) == 'sport':
            print('')
            print('                     🏃‍♀️三三☲=💨')
            print('( ﾟ-ﾟ)_ρ┳┻┳ﾟσ彡(ﾟoﾟ )              ❚█══█❚')
            print('                    ₍₍ ᕕ(´◓ω◓)ᕗ⁾⁾    ')
            print('')
            
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_sport['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_sport[paid_sport['date'].str.contains(your_date)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
     # outdoor       
        elif str.lower(your_interest) == 'outdoor':
            print('')
            print('────██──────▀▀▀██')
            print('──▄▀█▄▄▄─────▄▀█▄▄▄')
            print('▄▀──█▄▄──────█─█▄▄')
            print('─▄▄▄▀──▀▄───▄▄▄▀──▀▄')
            print('─▀───────▀▀─▀───────▀▀')
            print('')
            
            your_date = input('Which date? write here: dd.mm:  ')
            dates = paid_travel_out['date'].tolist()
            if str.lower(your_date) in dates:   
                contain_values = paid_travel_out[paid_travel_out['date'].str.contains(your_date)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print('€')
                print(contain_values[['price','name','links']].to_string(index=False, header=False),'\n')
            else:
                print('Sorry. No events on that day;')
                print('Tips:')
                print('1) Save your money and try a Free Event  ;) ')
                print('2) Change category')
                print('3) Change date','\n')
                
        
        else:
            print('_________________________________________________________________________________________________', '\n')
            print('              >>>>> Please, CHOOSE A PROPER CATEGORY NAME AND TRY AGAIN !!! <<<<<', '\n')
            print('_________________________________________________________________________________________________')
            print('')
            return best_tip_berlin() 
         
            
        
# FREE EVENTS  

    elif str.lower(your_budget) == 'no':    
        
        print('Let me recommend you the best free events in Berlin','\n')           
        print('Which event category you would prefer?')
        your_interest2 = input('Select one of these: film, music, science, outdoor, community, sport  --->  ')
        print('')
        
    # music
        if str.lower(your_interest2) == 'music':
            print('')
            print('    █▀█▄▄▄▄     ██▄')
            print('    █▀▄▄▄▄█     █▀▀█')
            print(' ▄▄▄█     █  ▄▄▄█')
            print('██▀▄█ ▄██▀█ ███▀█')
            print(' ▀▀▀  ▀█▄█▀ ▀█▄█▀')
            print('')
            
            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_music['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_music[free_music['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')

            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Park in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                    
                    
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2)
                        print('Tip 1:    '+ random_choice1, '\n')
                        
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                else:
                    print('_________________________________________________________________________________________________', '\n')
                    print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                    print('_________________________________________________________________________________________________', '\n')
                    print('')  
                    return best_tip_berlin()
                
                
            
    # film        
        elif str.lower(your_interest2) == 'film':
            print('')
            print('    ░▀▄░░▄▀')
            print('▄▄▄██▄▄▄▄▄░▀█▀▐░▌')
            print('█▒░▒░▒░█▀█░░█░▐░▌')
            print('█░▒░▒░▒█▀█░░█░░█')
            print('█▄▄▄▄▄▄███══════')
            print('')
            
            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_film['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_film[free_film['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')
            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Park in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2, '\n')
                        print('Tip 1:    '+ random_choice1)
                        
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                else:
                    print('_________________________________________________________________________________________________', '\n')
                    print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                    print('_________________________________________________________________________________________________', '\n')
                    print('')  
                    return best_tip_berlin()
                
                    
            
     # community       
        elif str.lower(your_interest2) == 'community':
            print('')
            print('               ▄▄   ▐█')
            print('   ▄▄▄   ▄██▄ █▀   █ ▄')
            print(' ▄██▀█▌ ██▄▄ ▐█▀▄ ▐█▀')
            print('▐█▀▀▌   ▄▀▌ ▌ █ ▌  ▌ ▌')
            print('▌▀▄ ▐  ▀▄ ▐▄ ▐▄▐▄ ▐▄ ▐▄')
            print('')

            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_community['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_community[free_community['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')
            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Park in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                        
                
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2)
                        print('Tip 1:    '+ random_choice1)
                    
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                else:
                    print('_________________________________________________________________________________________________', '\n')
                    print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                    print('_________________________________________________________________________________________________', '\n')
                    print('')  
                    return best_tip_berlin()
                    
            
      # science      
        elif str.lower(your_interest2) == 'science':
            print('')
            print('  ▄████▀█▄')
            print(' ▄█████████████████▄')
            print('▄█████.▼.▼.▼.▼.▼.▼▼▼▼')
            print('▄███████▄.▲.▲▲▲▲▲▲▲▲')
            print('████████████████████▀▀')
            print('───')
            print('')
            
            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_ScienceTech['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_ScienceTech[free_ScienceTech['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')
            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Park in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2)
                        print('Tip 1:    '+ random_choice1)
                    
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                else:
                    print('_________________________________________________________________________________________________', '\n')
                    print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                    print('_________________________________________________________________________________________________', '\n')
                    print('')  
                    return best_tip_berlin()
                    
                
     # sport      
        elif str.lower(your_interest2) == 'sport':
            print('')
            print('                     🏃‍♀️三三☲=💨')
            print('( ﾟ-ﾟ)_ρ┳┻┳ﾟσ彡(ﾟoﾟ )              ❚█══█❚')
            print('                    ₍₍ ᕕ(´◓ω◓)ᕗ⁾⁾    ')
            print('')
            
            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_sport['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_sport[free_sport['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')
            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Park in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                        
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2)
                        print('Tip 1:    '+ random_choice1, '\n')
                        
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                    
                else:
                    print('_________________________________________________________________________________________________', '\n')
                    print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                    print('_________________________________________________________________________________________________', '\n')
                    print('')  
                    return best_tip_berlin()
            
                    
                
    # outdoor   
        elif str.lower(your_interest2) == 'outdoor':
            print('')
            print('────██──────▀▀▀██')
            print('──▄▀█▄▄▄─────▄▀█▄▄▄')
            print('▄▀──█▄▄──────█─█▄▄')
            print('─▄▄▄▀──▀▄───▄▄▄▀──▀▄')
            print('─▀───────▀▀─▀───────▀▀')
            print('')
            
            your_date2 = input('Which date? write here: dd.mm:')
            dates = free_travel_out['date'].tolist()
            if str.lower(your_date2) in dates:   
                contain_values = free_travel_out[free_travel_out['date'].str.contains(your_date2)]
                print('Here your events!!! * Enjoy!!! * :','\n')
                print(contain_values[['date', 'name', 'link']].to_string(index=False, header=False), '\n')
            else:
                print('Sorry. No events on that day; but here a tip for your best experience in the nature.', '\n')
                print('Would you prefer to spend your day more in a park or in a lake?')
                nature_exp = input('Please, indicate here: ')
                
                if str.lower(nature_exp) == 'park':
                    print('')
                    print(' ──▒▒▒▒▒▒▒▒───▒▒▒▒▒▒▒▒')
                    print(' ─▒▐▒▐▒▒▒▒▌▒─▒▒▌▒▒▐▒▒▌▒')
                    print(' ──▒▀▄█▒▄▀▒───▒▀▄▒▌▄▀▒')
                    print(' ─────██─────────██')
                    print(' ░░░▄▄██▄░░░░░░░▄██▄░░░')
                    print('')
                    
                    print('Which area?')
                    choose_area_park = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area = berlin_parks['district'].tolist()
                    if str.lower(choose_area_park) in area:
                        selected_area = berlin_parks[berlin_parks['district'].str.contains(choose_area_park)]
                        random_choice1 = random.choice(selected_area['park_name'].values)
                        print('')
                        print('Suggested Parks in '+ choose_area_park)
                        print('Tip 1:    '+ random_choice1, '\n')
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                
                
                elif str.lower(nature_exp) == 'lake':
                    print('')
                    print('\033[1m'+'人人人人　へ( ﾟｪﾟ)＿ 人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('\033[1m'+'人人人人·.¸¸.·´¯`·.><((((((((((((((((º>·.¸¸.·´¯`·.'+'\033[0m')
                    print('\033[1m'+'人人人人人人人人人人人人人人人人人人人人人人人人人人人人人'+'\033[0m')
                    print('')
                    
                    print('Which area?')
                    choose_area_lake2 = input('Write here: mitte, charlottenburg-wilmersdorf, lichtenberg, pankow, reicknickendorf, steglitz-zehlendorf, friedrichshain-kreuzberg, marzahn-hellersdorf, neukölln, treptow-köpenick, spandau or tempelhof-schöneberg  ----->   ')
                    area2 = berlin_lakes['district'].tolist()
                    if str.lower(choose_area_lake2) in area2:
                        selected_area2 = berlin_lakes[berlin_lakes['district'].str.contains(choose_area_lake2)]
                        random_choice1 = random.choice(selected_area2['lake_name'].values)
                        print('Suggested Lake in '+ choose_area_lake2)
                        print('Tip 1:    '+ random_choice1, '\n')
                    else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()
                
                
                else:
                        print('_________________________________________________________________________________________________', '\n')
                        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
                        print('_________________________________________________________________________________________________', '\n')
                        print('')  
                        return best_tip_berlin()  
                       
                
            
        else:
            print('_________________________________________________________________________________________________', '\n')
            print('              >>>>> Please, CHOOSE A PROPER CATEGORY NAME AND TRY AGAIN !!! <<<<<', '\n')
            print('_________________________________________________________________________________________________', '\n')
            print('')
            return best_tip_berlin()  
        
    else:    
        print('_________________________________________________________________________________________________', '\n')
        print('                     >>>>> Please, CHECK YOUR TIPING AND TRY AGAIN !!! <<<<<', '\n')
        print('_________________________________________________________________________________________________', '\n')
        print('')  
        return best_tip_berlin()

        
best_tip_berlin()
# Out:
#          ▄▀          〈( ^.^)ノ                          ヘ(^o^ヘ)                 ░░▄▀▀▀▄░▄▄░░░░░░╠▓░░░░
#    █▀▀▀█▀█                                                                        ░░░▄▀▀▄█▄░▀▄░░░▓╬▓▓▓░░
#     ▀▄░▄▀       ¡¡¡  Welcome to the BEST TIP in * BERLIN SUMMER 2022 *  !!!      ░░▀░░░░█░▀▄░░░▓▓╬▓▓▓▓░
#      █                                                                           ░░░░░░▐▌░░░░▀▀███████▀
#    ▄▄█▄▄                 ﮩ٨ـﮩﮩ٨ـ♡ﮩ٨ـﮩﮩ٨ ───==≡≡ΣΣ((( つºل͜º)つ                     ▒▒▄██████▄▒▒▒▒▒▒▒▒▒▒▒▒
#
#
#
# To get you the Best Tip, we need some information from you.
