# %%
import sys
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import random
url = 'https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=1'

# %%
eventb_june = requests.get(url)
eventb_june.content
# Out:
# b'\n\n\n\n\n\n\n<!DOCTYPE html>\n    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#" lang="en-us" translate="no">\n\n    <head>\n        <title>\n    Berlin, Germany Events Next Month | Eventbrite\n</title>\n\n        <meta charset="utf-8" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta http-equiv="Content-Language" content="en" />\n        \n\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-32x32.png" sizes="32x32">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-194x194.png" sizes="194x194">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-96x96.png" sizes="96x96">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic
# ...

# %%
eventb_june = BeautifulSoup(eventb_june.content, 'html.parser')
eventb_june
# Out:
# <!DOCTYPE html>
#
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <title>
#     Berlin, Germany Events Next Month | Eventbrite
# </title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="en" http-equiv="Content-Language">
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# ...

# %%
events = []
for i in range(1,35):
    url = 'https://www.eventbrite.com/d/germany--berlin/events--next-month/?page='
    url = url + str(i)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    for name in names:
        events.append(name.get_text(strip=True).lower())


#iterations = range(1,35)
#for i in iterations:

    # assemble the url:
    #start_at= str(i)
    #url = "https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=" + start_at
    #response = requests.get(url)
    #soup = BeautifulSoup(response.content, "html.parser")
    #soup

# %%
events
# Out:
# ['openinfra summit berlin 2022',
#  'brlo brwfest 2022',
#  'italian market berlin - food, wine and music festival',
#  'darkest thoughts comedy: stand up from your thoughts',
#  'zalando zircle - berlin',
#  'kiezsalon w/ mario batkovic, hatis noit, park jiha and maria w horn',
#  'lesung: annabelle stehl & ava reed',
#  'english comedy berlin with pizza and shots',
#  'work awesome berlin 2022 – die konferenz zur zukunft der arbeit',
#  'new york comedy club - berlin: main show',
#  'großer pflanzenverkauf - berlin',
#  'sticks & stones berlin 2022 - europas größte lgbtiq+ job- & karrieremesse',
#  'happy hour',
#  'josua gottesdienst',
#  "sticks & stones 2022 – europe's largest lgbtiq+ job & career fair",
#  'steppt der bär open air',
#  'molly nilsson "extreme live"',
#  "spring in berlin '22 - pin collector meeting",
#  'saying the wrong thing: an english comedy hour in berlin(free entry)',
#  'larry schuba und western union',
# ...

# %%
june=[]
for k in soup.select('div.eds-is-hidden-accessible'): # [1::2] to get all the odd numbers
    x=k.get_text(strip=True).lower()
    june.append(x)

june
# Out:
# ['alma brasiliera. eine musikalische reise nach brasilien',
#  'alma brasiliera. eine musikalische reise nach brasilien',
#  'seminar: social media im beruf: online-marketing und pr',
#  'seminar: social media im beruf: online-marketing und pr',
#  'seminar: apps programmieren:  marketing-workshop mit apps & ki',
#  'seminar: apps programmieren:  marketing-workshop mit apps & ki',
#  'kommunikation verbessern, eskalation vermeiden',
#  'kommunikation verbessern, eskalation vermeiden',
#  'seminar: rechtsschutz im internet: abmahnungen und klagen vermeiden (mkz)',
#  'seminar: rechtsschutz im internet: abmahnungen und klagen vermeiden (mkz)',
#  'it-jobtag leipzig 2022',
#  'it-jobtag leipzig 2022',
#  'vdmno-jahresversammlung | ddmt 2022',
#  'vdmno-jahresversammlung | ddmt 2022']

# %%
: # [1::2] to get all the odd numbers
    x=i.get_text(strip=True).lower()
    june.append(x)

june

# %%
iterations = range(1, 35)

for i in iterations:
    start_at= str(i)
    url = "https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=" + start_at
    print(url)
# Out:
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=1
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=2
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=3
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=4
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=5
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=6
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=7
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=8
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=9
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=10
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=11
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=12
# https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=13
# ...

# %%
from time import sleep
from random import randint

# %%
pages = []

for i in iterations:

    # assemble the url:
    start_at= str(i)
    url = "https://www.eventbrite.com/d/germany--berlin/events--next-month/?page=" + start_at

    # download html with a get request:
    response = requests.get(url)

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))

    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
# Out:
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# ...

# %%
print(eventb_june .prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Berlin, Germany Events Next Month | Eventbrite
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="en" http-equiv="Content-Language">
#    <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# ...

# %%
soup = BeautifulSoup(pages[0].content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <title>
#     Berlin, Germany Events Next Month | Eventbrite
# </title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="en" http-equiv="Content-Language">
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/474372-rc2022-05-12_16.04-8109ed1/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# ...

# %%
soup1 = BeautifulSoup(pages[0:].content, "html.parser")
soup1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 soup1 = BeautifulSoup(pages[0:].content, "html.parser")
#       2 soup1
#
# AttributeError: 'list' object has no attribute 'content'

# %%
soup.select('div.eds-is-hidden-accessible')
# Out:
# [<div class="eds-is-hidden-accessible">OpenInfra Summit Berlin 2022</div>,
#  <div class="eds-is-hidden-accessible">OpenInfra Summit Berlin 2022</div>,
#  <div class="eds-is-hidden-accessible">Italian Market Berlin - Food, Wine and Music Festival</div>,
#  <div class="eds-is-hidden-accessible">Italian Market Berlin - Food, Wine and Music Festival</div>,
#  <div class="eds-is-hidden-accessible">BRLO BRWFEST 2022</div>,
#  <div class="eds-is-hidden-accessible">BRLO BRWFEST 2022</div>,
#  <div class="eds-is-hidden-accessible">Darkest Thoughts Comedy: Stand up from your thoughts</div>,
#  <div class="eds-is-hidden-accessible">Darkest Thoughts Comedy: Stand up from your thoughts</div>,
#  <div class="eds-is-hidden-accessible">Kiezsalon w/ Mario Batkovic, Hatis Noit, Park Jiha and Maria W Horn</div>,
#  <div class="eds-is-hidden-accessible">Kiezsalon w/ Mario Batkovic, Hatis Noit, Park Jiha and Maria W Horn</div>,
# ...

# %%
soup1.select('div.eds-is-hidden-accessible')
# Out:
# [<div class="eds-is-hidden-accessible">Larry Schuba und Western Union</div>,
#  <div class="eds-is-hidden-accessible">Larry Schuba und Western Union</div>,
#  <div class="eds-is-hidden-accessible">Elektrische Meile</div>,
#  <div class="eds-is-hidden-accessible">Elektrische Meile</div>,
#  <div class="eds-is-hidden-accessible">BERLIN MUSIC VIDEO AWARDS 2022</div>,
#  <div class="eds-is-hidden-accessible">BERLIN MUSIC VIDEO AWARDS 2022</div>,
#  <div class="eds-is-hidden-accessible">Transformational Breathwork</div>,
#  <div class="eds-is-hidden-accessible">Transformational Breathwork</div>,
#  <div class="eds-is-hidden-accessible">BERLIN FREAK BURLESQUE CIRCUS SHOW</div>,
#  <div class="eds-is-hidden-accessible">BERLIN FREAK BURLESQUE CIRCUS SHOW</div>,
#  <div class="eds-is-hidden-accessible">More Town Soul - The Best of Motown and more</div>,
#  <div class="eds-is-hidden-accessible">More Town Soul - The Best of Motown and more</div>,
# ...

# %%
june=[]
for i in eventb_june.select('div.eds-is-hidden-accessible')[1::2]: # [1::2] to get all the odd numbers
    x=i.get_text(strip=True).lower()
    june.append(x)

june
# Out:
# ['openinfra summit berlin 2022',
#  'italian market berlin - food, wine and music festival',
#  'brlo brwfest 2022',
#  'darkest thoughts comedy: stand up from your thoughts',
#  'kiezsalon w/ mario batkovic, hatis noit, park jiha and maria w horn',
#  'lesung: annabelle stehl & ava reed',
#  'english comedy berlin with pizza and shots',
#  'zalando zircle - berlin',
#  'new york comedy club - berlin: main show',
#  'sticks & stones berlin 2022 - europas größte lgbtiq+ job- & karrieremesse',
#  'happy hour',
#  'work awesome berlin 2022 – die konferenz zur zukunft der arbeit',
#  'josua gottesdienst',
#  'großer pflanzenverkauf - berlin',
#  'steppt der bär open air',
#  "sticks & stones 2022 – europe's largest lgbtiq+ job & career fair",
#  'molly nilsson "extreme live"',
#  'sometimes people are shit - berlins only english comedy show!',
#  "spring in berlin '22 - pin collector meeting",
#  'saying the wrong thing: an english comedy hour in berlin(free entry)']

# %%
eventb_june.select('div.eds-event-card-content__primary-content')
# Out:
# [<div class="eds-event-card-content__primary-content"><a aria-label="" class="eds-event-card-content__action-link" href="https://www.eventbrite.com/e/openinfra-summit-berlin-2022-tickets-211374997307?aff=ebdssbdestsearch" rel="noopener" tabindex="0" target="_blank"><h3 class="eds-event-card-content__title eds-text-color--ui-800 eds-text-bl eds-text-weight--heavy"><div data-spec="event-card__formatted-name"><div class="eds-is-hidden-accessible">OpenInfra Summit Berlin 2022</div><div aria-hidden="true" class="eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy" data-spec="event-card__formatted-name--content" role="presentation">OpenInfra Summit Berlin 2022</div></div></h3></a><div class="eds-event-card-content__sub-title eds-text-color--primary-brand eds-l-pad-bot-1 eds-l-pad-top-2 eds-text-weight--heavy eds-text-bm">Tue, Jun 7, 8:00 AM</div></div>,
# ...

# %%
june_dates=[]
for i in eventb_june.select('.eds-event-card-content__sub-title')[1::2]:
    x=i.get_text(strip=True)[0:11].lower()
    june_dates.append(x)

june_dates
# Out:
# ['tue, jun 7, 8:00 am',
#  'sat, jun 25, 12:00 pm + 1 more event',
#  'fri, jun 17, 4:00 pm',
#  'wed, jun 8, 7:59 pm + 1 more event',
#  'sat, jun 18, 5:00 pm',
#  'tue, jun 14, 8:15 pm',
#  'fri, jun 3, 7:00 pm + 7 more events',
#  'fri, jun 10, 1:00 pm',
#  'sun, jun 5, 7:30 pm + 4 more events',
#  'sat, jun 11, 10:00 am',
#  'thu, jun 9, 5:30 pm + 1 more event',
#  'thu, jun 2, 8:00 am',
#  'sun, jun 5, 11:00 am + 3 more events',
#  'thu, jun 2, 10:00 am',
#  'sat, jun 11, 2:00 pm',
#  'sat, jun 11, 10:00 am',
#  'thu, jun 9, 7:00 pm',
#  'fri, jun 3, 10:00 pm + 3 more events',
#  'fri, jun 10, 5:00 pm',
#  'wed, jun 1, 7:59 pm + 1 more event']

# %%
june_price=[]
for i in eventb_june.select('.eds-event-card-content__sub-title')[1::2]:
    x=i.get_text(strip=True).lower()
    june_price.append(x)

june_price

# %%
#root > div > div.eds-structure__body > div > div > div > div.eds-fixed-bottom-bar-layout__content > div > main > div > div > section.search-base-screen__search-panel > div.search-results-panel-content > div > ul > li:nth-child(3) > div > div > div.search-event-card-square-image > div > div > div > article > div.eds-event-card-content__content-container.eds-l-pad-right-4 > div > div > div.eds-event-card-content__sub-content > div:nth-child(2)
